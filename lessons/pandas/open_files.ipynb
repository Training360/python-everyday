# %%
import pandas as pd

# %%
df_csv = pd.read_csv("./files/employees.csv")
df_csv
# Out:
#        id   first_name  last_name                         email    gender  \
# 0       1        Jayne  Burchmore        jburchmore0@unicef.org    Female
# 1       2         Anna   De Paoli                adepaoli1@t.co    Female
# 2       3       Abbott   Itzchaki      aitzchaki2@bloglovin.com      Male
# 3       4      Callean      Mayer       cmayer3@cyberchimps.com      Male
# 4       5         Burl  Heikkinen        bheikkinen4@unesco.org      Male
# ..    ...          ...        ...                           ...       ...
# 995   996  Cairistiona  Mullinger        cmullingerrn@yahoo.com    Female
# 996   997      Esmaria      Lagde               elagdero@pen.io    Female
# 997   998        Benni   Gilderoy          bgilderoyrp@ox.ac.uk    Female
# 998   999      Phineas    Dunmuir         pdunmuirrq@elpais.com  Bigender
# 999  1000     Starlene  Rittmeyer  srittmeyerrr@squarespace.com    Female
#
#      yearly_salary  years_of_experience
# 0            78395                   23
# 1           102972                   28
# 2           178876                   12
# 3           177153                   13
# 4           140490                   38
# ..             ...                  ...
# 995         144155                    8
# 996          96353                   15
# 997         185707                    8
# 998         180372                    2
# 999          32228                   11
#
# [1000 rows x 7 columns]

# %%
df_json = pd.read_json("./files/employees.json")
df_json
# Out:
#        id   first_name  last_name                         email    gender  \
# 0       1        Jayne  Burchmore        jburchmore0@unicef.org    Female
# 1       2         Anna   De Paoli                adepaoli1@t.co    Female
# 2       3       Abbott   Itzchaki      aitzchaki2@bloglovin.com      Male
# 3       4      Callean      Mayer       cmayer3@cyberchimps.com      Male
# 4       5         Burl  Heikkinen        bheikkinen4@unesco.org      Male
# ..    ...          ...        ...                           ...       ...
# 995   996  Cairistiona  Mullinger        cmullingerrn@yahoo.com    Female
# 996   997      Esmaria      Lagde               elagdero@pen.io    Female
# 997   998        Benni   Gilderoy          bgilderoyrp@ox.ac.uk    Female
# 998   999      Phineas    Dunmuir         pdunmuirrq@elpais.com  Bigender
# 999  1000     Starlene  Rittmeyer  srittmeyerrr@squarespace.com    Female
#
#      yearly_salary  years_of_experience
# 0            78395                   23
# 1           102972                   28
# 2           178876                   12
# 3           177153                   13
# 4           140490                   38
# ..             ...                  ...
# 995         144155                    8
# 996          96353                   15
# 997         185707                    8
# 998         180372                    2
# 999          32228                   11
#
# [1000 rows x 7 columns]

# %%
df_xml = pd.read_xml("./files/employees.xml")
df_xml
# Out:
#        id   first_name  last_name                         email    gender  \
# 0       1        Jayne  Burchmore        jburchmore0@unicef.org    Female
# 1       2         Anna   De Paoli                adepaoli1@t.co    Female
# 2       3       Abbott   Itzchaki      aitzchaki2@bloglovin.com      Male
# 3       4      Callean      Mayer       cmayer3@cyberchimps.com      Male
# 4       5         Burl  Heikkinen        bheikkinen4@unesco.org      Male
# ..    ...          ...        ...                           ...       ...
# 995   996  Cairistiona  Mullinger        cmullingerrn@yahoo.com    Female
# 996   997      Esmaria      Lagde               elagdero@pen.io    Female
# 997   998        Benni   Gilderoy          bgilderoyrp@ox.ac.uk    Female
# 998   999      Phineas    Dunmuir         pdunmuirrq@elpais.com  Bigender
# 999  1000     Starlene  Rittmeyer  srittmeyerrr@squarespace.com    Female
#
#      yearly_salary  years_of_experience
# 0            78395                   23
# 1           102972                   28
# 2           178876                   12
# 3           177153                   13
# 4           140490                   38
# ..             ...                  ...
# 995         144155                    8
# 996          96353                   15
# 997         185707                    8
# 998         180372                    2
# 999          32228                   11
#
# [1000 rows x 7 columns]
